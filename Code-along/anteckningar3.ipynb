# %% [markdown]
# ![image.png](attachment:image.png)
# * nya theta, uppdaterad, "j:te epok"     ![image.png](attachment:image-2.png)
# * gamla theta - learning rate           ![image.png](attachment:image-3.png)
# * 2/m = m antalet samples
# * x = vår data
# * \ - y = label
