# %% [markdown]
# # Simpel bildbehandling(image processing)
# * ![image.png](attachment:image.png)
# * intensiteten i pixeln bestäms av värdet i matrisen (0,3 hade varit mer grå)
# * ju högre siffra, desto ljusare pixel är det
#
# ## Färgbilder RGB
# * ![image.png](attachment:image-2.png)
# * pixelns färg består av en kombination RGB
# * en pixels färgs bestäms av proportionerna av R, G, B, i pixelns position

# %% [markdown]
# ### matplotlib
# * import matplotlib.image as mpimg
# * img = mpimg("bild.png")
# * plt.imshow(img)
#
# *
# *
# * Kolla även på python OpenCV
