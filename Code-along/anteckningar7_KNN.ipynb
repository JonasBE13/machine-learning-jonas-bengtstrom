# %% [markdown]
# # KNN - K-nearest neighbour

# %% [markdown]
# 1. Räkna avstånd "d" mellan test sample "p" och träningsamples (vi sparar alla våra träning i minnet)
# 2. Sortera "d" i storleksordning.
# 3. Väljer "K" närmaste punkter.
# 4. Majoritetsröstning (6st var pikachu, 4st var pichu. Vi välljer Pikachu.)
#     (5v5, kollar det euklidiska avståndet istället.)

# %% [markdown]
# ___
# ## Regressionsfallet
# * plockar medelvärde av "k" närmaste grannarna
# * klassificering/regression
# *
# * ![image.png](attachment:image-2.png)
# * K = 3, klassificera som label 0, pga majoritetsröstning
# *
# * "Hur bestämmer jag k?"
# * K är en hyperparameter,
# * -> elbowplot
# * -> cross-validation
# ___
# ### Avstånd
# * beror på similarity measure
# * det euklidiska avståndet (euclidean distance):
# * ![image.png](attachment:image.png)
#
# ### cosine similarity
# * ![image.png](attachment:image-3.png)
# * dividerar på normen av p och q
# * Sc = similarity coefficient
# * ![image.png](attachment:image-4.png)
# *
# *
# * ![image.png](attachment:image-5.png)
# * två vektorer nära varandra = liten theta
# * två vektorer långt ifrån varandra = stor theta
# * P & q nära om theta liten --> cos theta nära 1
# * ![image.png](attachment:image-6.png)
# * ![image.png](attachment:image-8.png)
# * euclidean distance är den röda.
# * cosine är "vinkeln", theta är  vinkeln.
# * frekvensen skall inte spela någon roll när man jämför t.ex. dokument av fotboll + annan sport
# * vi kan inte jobba med text ifall vi inte överför dem till siffror och vektorer
# * natural language processing
