# %% [markdown]
# ## Anteckningar
#
# * Introduction to statistical learning
# * https://www.statlearning.com/
# * Bra bok att läsa^
# * Video lectures, finns i Kokchuns GitHub, -resurser
#
#
# ### Linjär regression
# * Y = Kx + m
# * ![image.png](attachment:image.png)
# * Independent = oberoende, dependent = beror på
#
# * ![image.png](attachment:image-2.png)
# * Beta0, Beta1; dem olika parametrarna vi har. Det är dessa vi ska träna för att dem ska passa in för vår data
#
# * ![image.png](attachment:image-3.png)
# * ska stå; x1 =
#
#
# * Vår csv-fil ser ut så här;
# * ![image.png](attachment:image-4.png)
# * ![image.png](attachment:image-5.png)
# * notation, xij, i - sample, j - feature
#
#
# * Hur skapar vi en linje som passar till punkterna på bästa sätt?
# * ![image.png](attachment:image-7.png)
# * Vi vill att vår linje har kortaste avståndet till våra punkter, till bästa sätt.
# * Minimera felet för varje punkt i kvadrat. RSS. Residual sum of squares.
# * ![image.png](attachment:image-6.png)
#
#
#
#
# * Det estimerade värdet för y är det värdet som är på linjen, eftersom vi har estimerat linjen.
# * ![image.png](attachment:image-8.png)
#
# * ![image.png](attachment:image-9.png)

# %% [markdown]
# ## Allt i en bild
# * ![image.png](attachment:image-2.png)

# %% [markdown]
# ___
# ### Hur gör man?

# %% [markdown]
# * För att göra detta;
# * ![image.png](attachment:image-2.png)
# * y vektorn är x multiplicerat med b0, b1
# * Viktigt med linjäralgebra, då vi kan få väldigt stora tal att bli en liter formel. Perfekt för när man skriver kod
#
# ### Fortsättning
# * Vår vektor:
# * ![image.png](attachment:image.png)
# * b0, b1, är fortfarande samma, eftersom vi har bestämt dessa parametrar
#
#
# ### Lösa ut b0, b1
# ### även multipel linjär regression
# * inverterar och multiplicerar med inversen av x
# * använd: normalekvation
# * ![image.png](attachment:image-3.png)
# * xty = xtx beta
#
# * inverterar:
# * ![image.png](attachment:image-5.png)
# * vi har löst ut en estimering av beta, en estimering baserat på data, därför betaHatt

# %% [markdown]
# ### Hur ser vårat x ut?
# * ![image.png](attachment:image-2.png)
# * [m x n]
#
# * m : samples
# * n-1 : features
# * ![image.png](attachment:image-3.png)

# %% [markdown]
# ## Stämmer normal ekvationen? -> dimensionsanalys
# * ![image.png](attachment:image.png)
