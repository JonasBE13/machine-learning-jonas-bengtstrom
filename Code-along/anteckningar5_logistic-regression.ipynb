# %% [markdown]
# # Lektion: Logistic regression

# %% [markdown]
# ## Supervised Learning
# * ![image.png](attachment:image.png)
# * kategorisk data i predictor matrisen, X är ok för linjär regression, men behöver göra en viss encoding.
# * smoker / no smoker. måste göra om till 0 / 1. binary.
# * annars underweight/normalweight/overweight, 1/2/3, lägga dem i ordning

# %% [markdown]
# ## Kategorisk ex
# ### Program
# * 1. AI
# * 2. C#
# * 3. Java
# * ![image.png](attachment:image.png)
# ### one-hot encoding
# * ![image.png](attachment:image-2.png)
# * från en kolonn har vi skapat 3 features
#
# ### dummy encoding
# * ![image.png](attachment:image-4.png)
# * färre dimensioner, mer fördelaktig än one-hot encoding för machine learning

# %% [markdown]
# ## Vid kategorisk respons
# * ![image.png](attachment:image.png)
# * vad betyder lika långt? en felaktig tolkning att sätta siffror på responsen.

# %% [markdown]
# ## Binär repsons
# * ![image.png](attachment:image.png)
# * ![image.png](attachment:image-2.png)
# * över x0, elakartad. under x0 godartad.
# * vår x0 hade utökat, ifall vi hade haft den elak tumören längst upp till höger
# * ![image.png](attachment:image-3.png)
#
# ### Vi vill modellera:
# * ![image.png](attachment:image-4.png)
# * Sannolikheten att vi får en elakaratad givet en viss storlek på tumören.
# * Vill ha en S-kurva (sigmoidkurva)
# *  Har krav på att den ska vara mellan 0 och 1.
# * ![image.png](attachment:image-5.png)
# ### Vi vill undersöka:
# * ![image.png](attachment:image-9.png)
# * ![image.png](attachment:image-7.png)
# * går mot oändligheten
# * ![image.png](attachment:image-8.png)
# * går mot negativa oändligheten
# * ![image.png](attachment:image-6.png)
# * x går mot 0
#
# ## Kontentan
# * ![image.png](attachment:image-11.png)
# * Vi behöver hitta b0 och b1 för att få den aatt passa så bra som möjligt till vår data

# %% [markdown]
# ## Vi kan skriva om vår logistiska funktion
# * ![image.png](attachment:image.png)
# * ![image.png](attachment:image-2.png)
# * ![image.png](attachment:image-3.png)
# * Sannolikhetne för "Ja" och sannolikheten för "Nej". Odds.
# * ![image.png](attachment:image-4.png)

# %% [markdown]
# ## Exempel 1 av 100 elaka
# * ![image.png](attachment:image.png)
# * har man ett OR kan man gå åt andra hållet för att räkna ut sannolikheten.

# %% [markdown]
# ## Logaritm
# * ![image.png](attachment:image.png)
# * Detta uttryck är olinjär just nu: v
# * ![image.png](attachment:image-2.png)
# * Logit/ log odds
# * logistisk regression har logit som är linjär i x.
# ____
# * behöver estimera b0_hatt och b1_hatt från träningsdata
# * här används sklearn ^
# * --> MLE (Maximum likelihood estimation)
# * ![image.png](attachment:image-3.png)

# %% [markdown]
# ___
# ### Maximum likelihood estimation
# * ![image.png](attachment:image-5.png)
# * ![image.png](attachment:image.png)
# * joint probability
# * ![image.png](attachment:image-3.png)
# * Slh * slh * slh....
# * ![image.png](attachment:image-2.png)
# * ![image.png](attachment:image-4.png)
# * ![image.png](attachment:image-6.png)
# * typ lösa detta med numerisk approach, typ gradient descent
