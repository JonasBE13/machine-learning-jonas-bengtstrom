# %% [markdown]
# # Naive Bayes

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("../data/spam.csv", encoding="latin-1")
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df[df.columns[2:]]
# Out:
#      Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# ...         ...        ...        ...
# 5567        NaN        NaN        NaN
# 5568        NaN        NaN        NaN
# 5569        NaN        NaN        NaN
# 5570        NaN        NaN        NaN
# 5571        NaN        NaN        NaN
#
# [5572 rows x 3 columns]

# %%
df_no_nan = df.dropna(axis=1)
df_no_nan.columns = ["class", "content"]
df_no_nan.head()
# Out:
#   class                                            content
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
sns.countplot(data=df_no_nan, x="class")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
df = pd.get_dummies(df_no_nan, columns=["class"], drop_first=True)
X, y = df["content"],df["class_spam"]
X.head()
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: content, dtype: object

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: class_spam, dtype: uint8

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

tfidf_vectorizer = TfidfVectorizer(stop_words="english")

print(tfidf_vectorizer.get_stop_words())
type(tfidf_vectorizer)
# Out:
# frozenset({'hence', 'we', 'yourselves', 'around', 'him', 'from', 'out', 'only', 'few', 'one', 'could', 'at', 'nevertheless', 'by', 'cant', 'anyone', 'herein', 'a', 'also', 'somehow', 'again', 'none', 'such', 'being', 'too', 'several', 'his', 'even', 'anywhere', 'same', 'ours', 'hers', 'meanwhile', 'made', 'due', 'side', 'whereupon', 'might', 'moreover', 'no', 'everything', 'hereafter', 'sometime', 'against', 'either', 'becomes', 'among', 'someone', 'call', 'thru', 'that', 'in', 'thence', 'be', 'hasnt', 'it', 'yours', 'otherwise', 'whereby', 'whatever', 'toward', 'hereby', 'not', 'top', 'first', 'wherever', 'much', 'since', 'therein', 'ourselves', 'part', 'name', 'were', 'everyone', 'rather', 'inc', 'former', 'where', 'up', 'everywhere', 'throughout', 'he', 'namely', 'them', 'another', 'formerly', 'indeed', 'is', 'perhaps', 'their', 'about', 'besides', 'never', 'forty', 'as', 'beyond', 'nor', 'whither', 'mine', 'thin', 'some', 'an', 'us', 'will', 'bottom', 'within', 'this', 'than', 'mostly', 'there', 'whence', 'anyhow', 'give', 'so', 'therefore', 'fire', 'whereafter', 'six', 'latterly', 'most', 'before', 'why', 'bill', 'thick', 'down', 'hundred', 'go', 'upon', 'i', 'twelve', 'themselves', 'other', 'third', 'all', 'each', 'anyway', 'move', 'well', 'noone', 'more', 'under', 'etc', 'whose', 'often', 'afterwards', 'these', 'please', 'would', 'has', 'next', 'once', 'last', 'amoungst', 'do', 'nowhere', 'been', 'alone', 'over', 'put', 'elsewhere', 'because', 'whole', 'yourself', 'back', 'across', 'co', 'you', 'somewhere', 'itself', 'if', 'above', 'enough', 'two', 'nobody', 'or', 'fill', 'whereas', 'was', 'something', 'me', 'to', 'get', 'amongst', 'himself', 'herself', 'become', 'anything', 'when', 'your', 'con', 'ltd', 'very', 'un', 'mill', 'keep', 'any', 'least', 'four', 'fifteen', 'full', 'system', 'three', 'see', 'eg', 'except', 'had', 'yet', 'thereupon', 'neither', 'behind', 'through', 'latter', 'became', 'with', 'both', 'else', 'done', 'becoming', 'while', 'show', 'hereupon', 'during', 'via', 'fifty', 'who', 'she', 'together', 'seem', 'still', 'take', 'eight', 'per', 'whoever', 'further', 'between', 'sixty', 'they', 'without', 'couldnt', 'though', 'detail', 'however', 'cry', 'after', 'seeming', 'on', 'nine', 'those', 'less', 'onto', 'beside', 'its', 'already', 'nothing', 'always', 'serious', 'cannot', 'have', 'her', 'thereby', 'below', 'then', 'must', 'sincere', 'thus', 'although', 'which', 'but', 'seemed', 'our', 'ten', 'wherein', 'ever', 'front', 'can', 'along', 'how', 're', 'almost', 'others', 'whenever', 'are', 'amount', 'ie', 'five', 'eleven', 'describe', 'for', 'beforehand', 'here', 'off', 'every', 'whether', 'my', 'de', 'the', 'until', 'find', 'seems', 'sometimes', 'and', 'into', 'myself', 'towards', 'thereafter', 'interest', 'own', 'now', 'am', 'of', 'found', 'what', 'empty', 'may', 'twenty', 'should', 'many', 'whom'})
# sklearn.feature_extraction.text.TfidfVectorizer

# %%
# tar bort stop_words från Dataframe X, sedan fit/transform på X
X_tfidf = tfidf_vectorizer.fit_transform(X)
X_tfidf
# Out:
# <5572x8404 sparse matrix of type '<class 'numpy.float64'>'
# 	with 43478 stored elements in Compressed Sparse Row format>

# %%
# TODO: försök att hitta ett ord som har värdet 1.0
X_tfidf.min(), X_tfidf.max()
# Out:
# (0.0, 1.0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=.33, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((3733, 8404), (1839, 8404))

# %%
fig, ax = plt.subplots(1,2)
sns.countplot(x=y_train, ax=ax[0])
sns.countplot(x=y_test, ax=ax[1])
# Out:
# <Axes: xlabel='class_spam', ylabel='count'>

# %% [markdown]
# ## Naive bayes

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

def evaluate_model(model):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(classification_report(y_test, y_pred))
    cm=confusion_matrix(y_test, y_pred)
    ConfusionMatrixDisplay(cm, display_labels=["Ham", "Spam"]).plot()

# %%
from sklearn.naive_bayes import MultinomialNB, ComplementNB, BernoulliNB


naive_bayes = dict(
    multinomial = MultinomialNB(), bernoulli=BernoulliNB(), complement=ComplementNB()
)

evaluate_model(naive_bayes["multinomial"])

# recall = TP/(TP+FN)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1587
#            1       1.00      0.75      0.86       252
#
#     accuracy                           0.97      1839
#    macro avg       0.98      0.88      0.92      1839
# weighted avg       0.97      0.97      0.96      1839

# %%
evaluate_model(naive_bayes["bernoulli"])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1587
#            1       0.98      0.81      0.89       252
#
#     accuracy                           0.97      1839
#    macro avg       0.97      0.91      0.94      1839
# weighted avg       0.97      0.97      0.97      1839

# %%
evaluate_model(naive_bayes["complement"])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96      1587
#            1       0.66      0.94      0.78       252
#
#     accuracy                           0.93      1839
#    macro avg       0.83      0.93      0.87      1839
# weighted avg       0.95      0.93      0.93      1839

# %% [markdown]
# ## Some other models

# %%
from sklearn.svm import LinearSVC

evaluate_model(LinearSVC())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1587
#            1       0.97      0.85      0.91       252
#
#     accuracy                           0.98      1839
#    macro avg       0.97      0.92      0.95      1839
# weighted avg       0.98      0.98      0.98      1839

# %%
from sklearn.ensemble import RandomForestClassifier

evaluate_model(RandomForestClassifier())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1587
#            1       1.00      0.84      0.91       252
#
#     accuracy                           0.98      1839
#    macro avg       0.99      0.92      0.95      1839
# weighted avg       0.98      0.98      0.98      1839

# %% [markdown]
# ## Combine different models
#
# - majority vote
# - class with most votes wins (hard voting)
# - class with highest probability wins (soft voting)

# %%
from sklearn.ensemble import VotingClassifier

vote_clf = VotingClassifier([
    ("random_forest", RandomForestClassifier()),
    ("svc", LinearSVC()),
    ("naive_complement", ComplementNB()),
    ("naive_multinomial", MultinomialNB()),
    ("naive_bernoulli", BernoulliNB())
])
# jag tror att default är voting ="hard"
evaluate_model(vote_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1587
#            1       1.00      0.86      0.92       252
#
#     accuracy                           0.98      1839
#    macro avg       0.99      0.93      0.96      1839
# weighted avg       0.98      0.98      0.98      1839

# %%
from sklearn.ensemble import VotingClassifier

vote_clf = VotingClassifier([
    ("random_forest", RandomForestClassifier()),
    ("svc", LinearSVC()),
    ("naive_complement", ComplementNB()),
    ("naive_multinomial", MultinomialNB()),
    ("naive_bernoulli", BernoulliNB())
], voting = "hard")
# jag tror att default är voting ="hard"
evaluate_model(vote_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1587
#            1       1.00      0.85      0.92       252
#
#     accuracy                           0.98      1839
#    macro avg       0.99      0.92      0.95      1839
# weighted avg       0.98      0.98      0.98      1839

# %%
from sklearn.ensemble import VotingClassifier

        # SOFT VOTE

vote_clf = VotingClassifier([
    ("random_forest", RandomForestClassifier()),
    #("svc", LinearSVC()),
    ("naive_complement", ComplementNB()),
    ("naive_multinomial", MultinomialNB()),
    ("naive_bernoulli", BernoulliNB())
], voting = "soft")

evaluate_model(vote_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1587
#            1       1.00      0.86      0.92       252
#
#     accuracy                           0.98      1839
#    macro avg       0.99      0.93      0.96      1839
# weighted avg       0.98      0.98      0.98      1839

# %% [markdown]
# ## Testing out a model - "deploy"
#
# - assume we choose vote_clf

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([("tfidf", TfidfVectorizer(stop_words="english")), ("vote", vote_clf)])

# fits on all data

pipe.fit(X,y)
pipe.predict(["Come and collect your $1000 Bitcoins!"])
# Out:
# array([0], dtype=uint8)

# %%
pipe.predict(["You will win $1000 for free!"])
# Out:
# array([1], dtype=uint8)

# %%
pipe.predict(["love bitcoin"])
# Out:
# array([0], dtype=uint8)

# %%
pipe.predict(["You get $500"])
# Out:
# array([1], dtype=uint8)
